# %%
# !pip install pymysql

# %%
import pymysql

# %%
dbcon=pymysql.connect(host='localhost',user='root',password='Poorvi',database='google')

# %%
dbcon

# %%
import pandas as pd

# %%
df = pd.read_sql_query("select * from employee",con=dbcon)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_15388\3418900563.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("select * from employee",con=dbcon)

# %%
df
# Out:
#     emp_ID  emp_NAME DEPT_NAME  SALARY
# 0      102  Rajkumar        HR   10000
# 1      103     Akbar        IT    4000
# 2      104    Dorvin   Finance    6500
# 3      105     Rohit        HR    3000
# 4      106    Rajesh   Finance    5000
# 5      107     Preet        HR    7000
# 6      108    Maryam     Admin    4000
# 7      109    Sanjay        IT    6500
# 8      110   Vasudha        IT    7000
# 9      111   Melinda        IT    8000
# 10     112     Komal        IT   10000
# 11     113   Gautham     Admin    2000
# 12     114   Manisha        HR    3000
# 13     115   Chandni        IT    4500
# 14     116     Satya   Finance    6500
# 15     117    Adarsh        HR    3500
# 16     118   Tejaswi   Finance    5500
# 17     119      Cory        HR    8000
# 18     120    Monica     Admin    5000
# 19     121   Rosalin        IT    6000
# 20     122   Ibrahim        IT    8000
# 21     123    Vikram        IT    8000
# 22     124   Dheeraj        IT   11000

# %%
df[df['emp_ID']==102][['emp_NAME','SALARY']]
# Out:
#    emp_NAME  SALARY
# 0  Rajkumar   10000

# %%
df1 = pd.read_sql_query("select * from employee where salary>4000",con=dbcon)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6472\644931460.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query("select * from employee where salary>4000",con=dbcon)

# %%
df1
# Out:
#     emp_ID  emp_NAME DEPT_NAME  SALARY
# 0      102  Rajkumar        HR   10000
# 1      104    Dorvin   Finance    6500
# 2      106    Rajesh   Finance    5000
# 3      107     Preet        HR    7000
# 4      109    Sanjay        IT    6500
# 5      110   Vasudha        IT    7000
# 6      111   Melinda        IT    8000
# 7      112     Komal        IT   10000
# 8      115   Chandni        IT    4500
# 9      116     Satya   Finance    6500
# 10     118   Tejaswi   Finance    5500
# 11     119      Cory        HR    8000
# 12     120    Monica     Admin    5000
# 13     121   Rosalin        IT    6000
# 14     122   Ibrahim        IT    8000
# 15     123    Vikram        IT    8000
# 16     124   Dheeraj        IT   11000

# %%
df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df1.info()
#
# NameError: name 'df1' is not defined

# %%
df.shape
# Out:
# (23, 4)

# %%
df.describe()
# Out:
#           emp_ID        SALARY
# count   23.00000     23.000000
# mean   113.00000   6173.913043
# std      6.78233   2410.246572
# min    102.00000   2000.000000
# 25%    107.50000   4250.000000
# 50%    113.00000   6500.000000
# 75%    118.50000   8000.000000
# max    124.00000  11000.000000

# %%
df1.describe(include='all')
# Out:
#             emp_ID  emp_NAME DEPT_NAME        SALARY
# count    17.000000        17        17     17.000000
# unique         NaN        17         4           NaN
# top            NaN  Rajkumar        IT           NaN
# freq           NaN         1         9           NaN
# mean    114.058824       NaN       NaN   7205.882353
# std       7.013118       NaN       NaN   1862.951485
# min     102.000000       NaN       NaN   4500.000000
# 25%     109.000000       NaN       NaN   6000.000000
# 50%     115.000000       NaN       NaN   7000.000000
# 75%     120.000000       NaN       NaN   8000.000000
# max     124.000000       NaN       NaN  11000.000000

# %%
df.head()
# Out:
#    emp_ID  emp_NAME DEPT_NAME  SALARY
# 0     102  Rajkumar        HR   10000
# 1     103     Akbar        IT    4000
# 2     104    Dorvin   Finance    6500
# 3     105     Rohit        HR    3000
# 4     106    Rajesh   Finance    5000

# %%
df.tail()
# Out:
#     emp_ID emp_NAME DEPT_NAME  SALARY
# 18     120   Monica     Admin    5000
# 19     121  Rosalin        IT    6000
# 20     122  Ibrahim        IT    8000
# 21     123   Vikram        IT    8000
# 22     124  Dheeraj        IT   11000

# %%
dbcon1 = pymysql.connect(host='127.0.0.1', user='root', password='Poorvi', database='company')

# %%
df_emp = pd.read_sql_query("select * from employee",con=dbcon1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6472\3392412192.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_emp = pd.read_sql_query("select * from employee",con=dbcon1)

# %%
df_emp
# Out:
#     employee_id             full_name  department_id             job_role  \
# 0          1001            John Smith              1                  CEO
# 1          1002          Sarah Goodes              1                  CFO
# 2          1003          Wayne Ablett              1                  CIO
# 3          1004        Michelle Carey              2           HR Manager
# 4          1005        Chris Matthews              3       Sales Manager
# 5          1006           Andrew Judd              4  Development Manager
# 6          1007       Danielle McLeod              5      Support Manager
# 7          1008          Matthew Swan              2    HR Representative
# 8          1009  Stephanie Richardson              2          Salesperson
# 9          1010            Tony Grant              3          Salesperson
# 10         1011         Jenna Lockett              4  Front-End Developer
# 11         1012      Michael Dunstall              4   Back-End Developer
# ...

# %%
df_dept = pd.read_sql_query("select * from department",con=dbcon1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6472\212862779.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_dept = pd.read_sql_query("select * from department",con=dbcon1)

# %%
df_dept
# Out:
#    department_id department_name
# 0              1       Executive
# 1              2              HR
# 2              3           Sales
# 3              4     Development
# 4              5         Support
# 5              6        Research

# %%
df_inner=df_emp.merge(df_dept,how='inner')

# %%
df_inner
# Out:
#     employee_id             full_name  department_id             job_role  \
# 0          1001            John Smith              1                  CEO
# 1          1002          Sarah Goodes              1                  CFO
# 2          1003          Wayne Ablett              1                  CIO
# 3          1004        Michelle Carey              2           HR Manager
# 4          1008          Matthew Swan              2    HR Representative
# 5          1009  Stephanie Richardson              2          Salesperson
# 6          1005        Chris Matthews              3       Sales Manager
# 7          1010            Tony Grant              3          Salesperson
# 8          1006           Andrew Judd              4  Development Manager
# 9          1011         Jenna Lockett              4  Front-End Developer
# 10         1012      Michael Dunstall              4   Back-End Developer
# 11         1013             Jane Voss              4   Back-End Developer
# ...

# %%
df_left=df_emp.merge(df_dept,how='left')

# %%
df_left
# Out:
#     employee_id             full_name  department_id             job_role  \
# 0          1001            John Smith              1                  CEO
# 1          1002          Sarah Goodes              1                  CFO
# 2          1003          Wayne Ablett              1                  CIO
# 3          1004        Michelle Carey              2           HR Manager
# 4          1005        Chris Matthews              3       Sales Manager
# 5          1006           Andrew Judd              4  Development Manager
# 6          1007       Danielle McLeod              5      Support Manager
# 7          1008          Matthew Swan              2    HR Representative
# 8          1009  Stephanie Richardson              2          Salesperson
# 9          1010            Tony Grant              3          Salesperson
# 10         1011         Jenna Lockett              4  Front-End Developer
# 11         1012      Michael Dunstall              4   Back-End Developer
# ...

# %%
df_out=df_dept.merge(df_emp,how='outer')

# %%
df_out
# Out:
#     department_id department_name  employee_id             full_name  \
# 0               1       Executive       1001.0            John Smith
# 1               1       Executive       1002.0          Sarah Goodes
# 2               1       Executive       1003.0          Wayne Ablett
# 3               2              HR       1004.0        Michelle Carey
# 4               2              HR       1008.0          Matthew Swan
# 5               2              HR       1009.0  Stephanie Richardson
# 6               3           Sales       1005.0        Chris Matthews
# 7               3           Sales       1010.0            Tony Grant
# 8               4     Development       1006.0           Andrew Judd
# 9               4     Development       1011.0         Jenna Lockett
# 10              4     Development       1012.0      Michael Dunstall
# 11              4     Development       1013.0             Jane Voss
# 12              5         Support       1007.0       Danielle McLeod
# ...

# %%
dbcon=pymysql.connect(host='localhost',user='root',password='Poorvi',database='google')

# %%
df=pd.read_sql_query("select * from employee",con=dbcon)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_15388\3146015921.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from employee",con=dbcon)

# %%
df
# Out:
#     emp_ID  emp_NAME DEPT_NAME  SALARY
# 0      102  Rajkumar        HR   10000
# 1      103     Akbar        IT    4000
# 2      104    Dorvin   Finance    6500
# 3      105     Rohit        HR    3000
# 4      106    Rajesh   Finance    5000
# 5      107     Preet        HR    7000
# 6      108    Maryam     Admin    4000
# 7      109    Sanjay        IT    6500
# 8      110   Vasudha        IT    7000
# 9      111   Melinda        IT    8000
# 10     112     Komal        IT   10000
# 11     113   Gautham     Admin    2000
# 12     114   Manisha        HR    3000
# 13     115   Chandni        IT    4500
# 14     116     Satya   Finance    6500
# 15     117    Adarsh        HR    3500
# 16     118   Tejaswi   Finance    5500
# 17     119      Cory        HR    8000
# 18     120    Monica     Admin    5000
# 19     121   Rosalin        IT    6000
# 20     122   Ibrahim        IT    8000
# 21     123    Vikram        IT    8000
# 22     124   Dheeraj        IT   11000

# %%
cursor=dbcon.cursor()

# %%
cursor

# %%
q="insert into employee values (%s,%s,%s,%s)"
data=(125,'Nancy','IT','40000')
# Execute the insert query
cursor.execute(q,data)
# Commit the transaction
dbcon.commit()

# %%
q="delete from employee where emp_ID=%s"
# Execute the insert query
cursor.execute(q,125)
# Commit the transaction
dbcon.commit()

# %%
q="update employee set emp_NAME=%s where emp_ID=%s"
data=('pooja',102)
# Execute the insert query
cursor.execute(q,data)
# Commit the transaction
dbcon.commit()

# %%
dbcon.close()
